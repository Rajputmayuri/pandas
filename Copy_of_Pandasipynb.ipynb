# %%
import pandas as pd
import numpy as np

# %% [markdown]
# > Upload the dataset of movie and find the following
#
# > 1. Column name
#
# > 2. values
#
# > 3. datatypes
#
# > 4. datatypes value counts
#
# > 5. find movie director names
#
# > 6. find sum of null values
#
# > 7. find statistics of 'actor_1_facebook_likes'
#
# > 8. add column 'actor_director_facebook_likes' which is summ of actors
#      and directors likes
#
# > 9. add column 'is_cast_likes_more' and fill it with bollean values if
#      'cast_total_facebook_likes' are greater than 'actor_director_facebook_likes'

# %%
df=pd.read_csv('/content/movie dataset.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
column_names = list(df.columns)
column_names
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
column_values=(df.values)
column_values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
column_datatype=df.dtypes
column_datatype
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
count_of_datatypes=df.dtypes.value_counts()
count_of_datatypes
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %%
name=df.director_name
name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
null_values=df.isnull()
null_values
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# ...     ...            ...                     ...       ...
# 4911  False          False                   False     False
# 4912  False           True                   False     False
# 4913  False          False                   False     False
# 4914  False          False                   False     False
# 4915  False          False                   False     False
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                       False                   False         False
# 1                       False                   False         False
# ...

# %%
count_of_null_values=df.isnull().sum()
count_of_null_values
# Out:
# color                             19
# director_name                    102
# num_critic_for_reviews            49
# duration                          15
# director_facebook_likes          102
# actor_3_facebook_likes            23
# actor_2_name                      13
# actor_1_facebook_likes             7
# gross                            862
# genres                             0
# actor_1_name                       7
# movie_title                        0
# num_voted_users                    0
# cast_total_facebook_likes          0
# actor_3_name                      23
# facenumber_in_poster              13
# plot_keywords                    152
# movie_imdb_link                    0
# num_user_for_reviews              21
# language                          12
# country                            5
# content_rating                   300
# budget                           484
# title_year                       106
# actor_2_facebook_likes            13
# ...

# %%
mean_of_column=df['actor_1_facebook_likes'].mean()
print("Mean of column is=",mean_of_column)
mean_of_column=df['actor_1_facebook_likes'].median()
print("Median of column is=",mean_of_column)
mean_of_column=df['actor_1_facebook_likes'].mode()
print("Mode of column is=",mean_of_column)
mean_of_column=df['actor_1_facebook_likes'].count()
print("count of column is=",mean_of_column)
# Out:
# Mean of column is= 6494.488490527602
# Median of column is= 982.0
# Mode of column is= 0    1000.0
# Name: actor_1_facebook_likes, dtype: float64
# count of column is= 4909

# %%
# add column 'actor_director_facebook_likes' which is summ of actors and directors likes
add_column=pd.DataFrame(df,columns=['color',
 'director_name',
 'num_critic_for_reviews',
 'duration',
 'director_facebook_likes',
 'actor_3_facebook_likes',
 'actor_2_name',
 'actor_1_facebook_likes',
 'gross',
 'genres',
 'actor_1_name',
 'movie_title',
 'num_voted_users',
 'cast_total_facebook_likes',
 'actor_3_name',
 'facenumber_in_poster',
 'plot_keywords',
 'movie_imdb_link',
 'num_user_for_reviews',
 'language',
 'country',
 'content_rating',
 'budget',
 'title_year',
 'actor_2_facebook_likes',
 'imdb_score',
 'aspect_ratio',
 'movie_facebook_likes',
 'actor_director_facebook_likes'])
add_column
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df['actor_director_facebook_likes']=df['director_facebook_likes']+df['actor_1_facebook_likes']+df['actor_2_facebook_likes']+df['actor_3_facebook_likes']
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# add column 'is_cast_likes_more' and fill it with boolean values if 'cast_total_facebook_likes' are greater than
#'actor_director_facebook_likes'

# %%
df['is_cast_likes_more']=df['cast_total_facebook_likes']>df['actor_director_facebook_likes']
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df1=pd.read_csv('/content/sample_data.csv',index_col=0)
df1
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
df1.nlargest(3,'age')
df1.head(3)
# Out:
#       state  color   food  age  height  score
# Jane     NY   blue  Steak   30     165  100.0
# Niko     TX  green      3    2      70    8.3
# Aaron    FL    red      4   12     120    9.0

# %%
u=df1.groupby('height').sum()
u
# Out:
# <ipython-input-17-76ab1c50ea02>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   u=df1.groupby('height').sum()
#         age  score
# height
# 70        2    8.3
# 80        4   99.0
# 120      12    9.0
# 150      69    2.2
# 165      30  100.0
# 172      33  100.0
# 180      32  100.0

# %%
df1.loc[['Niko','Penelope','Aaron'],'food']=[3,6,4]
df1
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green       3    2      70    8.3
# Aaron        FL    red       4   12     120    9.0
# Penelope     AL  white       6    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
df1.iloc[3:6,5]=99
df1
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green       3    2      70    8.3
# Aaron        FL    red       4   12     120    9.0
# Penelope     AL  white       6    4      80   99.0
# Dean         AK   gray  Cheese   32     180   99.0
# Christina    TX  black   Melon   33     172   99.0
# Cornelia     TX    red   Beans   69     150    2.2

# %%
df1.loc['Dean',['color','food']]=['white','melon']
df1
# Out:
#           state  color   food  age  height  score
# Jane         NY   blue  Steak   30     165    4.6
# Niko         TX  green      3    2      70    8.3
# Aaron        FL    red      4   12     120    9.0
# Penelope     AL  white      6    4      80   99.0
# Dean         AK  white  melon   32     180   99.0
# Christina    TX  black  Melon   33     172   99.0
# Cornelia     TX    red  Beans   69     150    2.2

# %%
df1.loc[df1['height']>150,'score']=100
df1
# Out:
#           state  color   food  age  height  score
# Jane         NY   blue  Steak   30     165  100.0
# Niko         TX  green      3    2      70    8.3
# Aaron        FL    red      4   12     120    9.0
# Penelope     AL  white      6    4      80   99.0
# Dean         AK  white  melon   32     180  100.0
# Christina    TX  black  Melon   33     172  100.0
# Cornelia     TX    red  Beans   69     150    2.2

# %%
df1['food']
# Out:
# Jane         Steak
# Niko             3
# Aaron            4
# Penelope         6
# Dean         melon
# Christina    Melon
# Cornelia     Beans
# Name: food, dtype: object

# %%
df1[['state','color','food']]
# Out:
#           state  color    food
# Jane         NY   blue   Steak
# Niko         TX  green    Lamb
# Aaron        FL    red   Mango
# Penelope     AL  white   Apple
# Dean         AK   gray  Cheese
# Christina    TX  black   Melon
# Cornelia     TX    red   Beans

# %%
df1.loc['Jane':'Aaron','state':'food':2]
# Out:
#       state   food
# Jane     NY  Steak
# Niko     TX   Lamb
# Aaron    FL  Mango

# %%
df1.loc['Niko': :6,'food':'height':2]
# Out:
#       food  height
# Niko  Lamb      70

# %%
df1.loc['Jane': :7 ,'color':'age':2]
# Out:
#      color  age
# Jane  blue   30

# %%
df1.loc['Niko': :6,'color': :6]
# Out:
#       color
# Niko  green

# %%
df1.iloc[0:2,0:2]
# Out:
#      state  color
# Jane    NY   blue
# Niko    TX  green

# %%
df1.iloc[0: :7,2: :6]
# Out:
#        food
# Jane  Steak

# %%
df1.iloc[1: ,:-1]
# Out:
#           state  color    food  age  height
# Niko         TX  green    Lamb    2      70
# Aaron        FL    red   Mango   12     120
# Penelope     AL  white   Apple    4      80
# Dean         AK   gray  Cheese   32     180
# Christina    TX  black   Melon   33     172
# Cornelia     TX    red   Beans   69     150

# %%
df1.loc[:,'age']>35
# Out:
# Jane         False
# Niko         False
# Aaron        False
# Penelope     False
# Dean         False
# Christina    False
# Cornelia      True
# Name: age, dtype: bool

# %%
df2=pd.read_csv('/content/stackoverflow_qa.csv')
df2
# Out:
#              id         creationdate  score  viewcount  \
# 0       5486226  2011-03-30 12:26:50      4       2113
# 1       5515021  2011-04-01 14:50:44      8       7015
# 2       5558607  2011-04-05 21:13:50      2       7392
# 3       6467832  2011-06-24 12:31:45      9      13056
# 4       7577546  2011-09-28 01:58:38      9       2488
# ...         ...                  ...    ...        ...
# 56393  47606711  2017-12-02 10:07:13      0         17
# 56394  47607549  2017-12-02 11:41:59     -1         41
# 56395  47609325  2017-12-02 15:16:26      0         33
# 56396  47609598  2017-12-02 15:45:40      2         18
# 56397  47611969  2017-12-02 19:59:09     -6         19
#
#                                                    title  answercount  \
# 0                               Rolling median in python            3
# 1           Compute a compounded return series in Python            3
# 2            Sort a pandas DataMatrix in ascending order            2
# ...

# %%
criteria=df2['viewcount']>=45678
criteria.head(30)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: viewcount, dtype: bool

# %%
criteria=df2['id']>=5000000
criteria
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 56393    True
# 56394    True
# 56395    True
# 56396    True
# 56397    True
# Name: id, Length: 56398, dtype: bool

# %%
criteria=df2['id']<=5000000
criteria
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Name: id, Length: 56398, dtype: bool

# %%
criteria1=df2['score']>5
criteria1
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Name: score, Length: 56398, dtype: bool

# %%
criteria2=df2['ans_name']=='Scott Boston'
criteria2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Name: ans_name, Length: 56398, dtype: bool

# %%
df2
# Out:
#              id         creationdate  score  viewcount  \
# 0       5486226  2011-03-30 12:26:50      4       2113
# 1       5515021  2011-04-01 14:50:44      8       7015
# 2       5558607  2011-04-05 21:13:50      2       7392
# 3       6467832  2011-06-24 12:31:45      9      13056
# 4       7577546  2011-09-28 01:58:38      9       2488
# ...         ...                  ...    ...        ...
# 56393  47606711  2017-12-02 10:07:13      0         17
# 56394  47607549  2017-12-02 11:41:59     -1         41
# 56395  47609325  2017-12-02 15:16:26      0         33
# 56396  47609598  2017-12-02 15:45:40      2         18
# 56397  47611969  2017-12-02 19:59:09     -6         19
#
#                                                    title  answercount  \
# 0                               Rolling median in python            3
# 1           Compute a compounded return series in Python            3
# 2            Sort a pandas DataMatrix in ascending order            2
# ...

# %%
cr2=(criteria1 | criteria2)
cr2
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Length: 56398, dtype: bool

# %%
print(df2.columns)
# Out:
# Index(['id', 'creationdate', 'score', 'viewcount', 'title', 'answercount',
#        'commentcount', 'favoritecount', 'quest_name', 'quest_rep', 'ans_name',
#        'ans_rep'],
#       dtype='object')

# %%
print(df2.shape)
# Out:
# (56398, 12)

# %%
criteria_all=criteria1 & criteria2
df2[criteria_all]
# Out:
#              id         creationdate  score  viewcount  \
# 44814  44877663  2017-07-03 04:07:59      9       1267
#
#                                               title  answercount  \
# 44814  Error: float object has no attribute notnull            3
#
#        commentcount  favoritecount   quest_name  quest_rep      ans_name  \
# 44814             2            1.0  Vivian  Tio      181.0  Scott Boston
#
#        ans_rep
# 44814  23611.0

# %%
df2.head(5)
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 1  5515021  2011-04-01 14:50:44      8       7015
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# ...

# %% [markdown]
# **Food Inspections Dataset**

# %%
df3=pd.read_csv('/content/food_inspections.csv',index_col=0)
df3
# Out:
#                            Facility Type             Risk  \
# DBA Name
# DANY'S TACOS                  Restaurant    Risk 1 (High)
# BILLY FOOD MARKET INC                NaN     Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA     Restaurant    Risk 1 (High)
# WILD GOOSE BAR & GRILL        Restaurant    Risk 1 (High)
# PUBLICAN TAVERN K1            Restaurant    Risk 1 (High)
# ...                                  ...              ...
# FRESH PANTRY               Grocery Store  Risk 2 (Medium)
# BUTTER                               NaN     Risk 3 (Low)
# SAFAH FOOD & LIQUOR INC    Grocery Store     Risk 3 (Low)
# RAINBOW GROCERY            Grocery Store     Risk 3 (Low)
# MAKIA FOOD                           NaN     Risk 3 (Low)
#
#                                           Address      Zip Inspection Date  \
# DBA Name
# DANY'S TACOS                 2857 S ST LOUIS AVE   60623.0      03/27/2017
# BILLY FOOD MARKET INC        3906 W ROOSEVELT RD   60624.0      03/27/2017
# ...

# %%
print(df3.columns)
# Out:
# Index(['Facility Type', 'Risk', 'Address', 'Zip', 'Inspection Date',
#        'Inspection Type', 'Results', 'Violations'],
#       dtype='object')

# %%
print(df3.shape)
# Out:
# (24063, 8)

# %%
df3.loc[['TAQUERIA HACIENDA TAPATIA','WILD GOOSE BAR & GRILL']]
# Out:
#                           Facility Type           Risk              Address  \
# DBA Name
# TAQUERIA HACIENDA TAPATIA    Restaurant  Risk 1 (High)      4125 W 26TH ST
# WILD GOOSE BAR & GRILL       Restaurant  Risk 1 (High)  4265 N LINCOLN AVE
#
#                                Zip Inspection Date        Inspection Type  \
# DBA Name
# TAQUERIA HACIENDA TAPATIA  60623.0      03/27/2017  License Re-Inspection
# WILD GOOSE BAR & GRILL     60618.0      03/27/2017                Canvass
#
#                           Results  \
# DBA Name
# TAQUERIA HACIENDA TAPATIA    Pass
# WILD GOOSE BAR & GRILL       Fail
#
#                                                                   Violations
# DBA Name
# TAQUERIA HACIENDA TAPATIA  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# WILD GOOSE BAR & GRILL     16. FOOD PROTECTED DURING STORAGE, PREPARATION...

# %%
df3.loc['TAQUERIA HACIENDA TAPATIA':'WILD GOOSE BAR & GRILL', 'Risk':'Results':5]
# Out:
#                                     Risk Results
# DBA Name
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Fail

# %%
# what is risk of restaurant SCRUB A DUB
df3.loc['SCRUB A DUB':'SCRUB A DUB','Risk': :7]
# Out:
#                         Risk
# DBA Name
# SCRUB A DUB  Risk 2 (Medium)

# %%
#select all columns from the 500th restaurant to the 510th
df3.iloc[500:511]
# Out:
#                                   Facility Type             Risk  \
# DBA Name
# THE MECCA RESTAURANT                 Restaurant    Risk 1 (High)
# L & T CHINA FAST WOK INC.            Restaurant    Risk 1 (High)
# SCHNEIDER  SENIOR  APARTMENT       Golden Diner    Risk 1 (High)
# ECKHARDT CAFE                        Restaurant    Risk 1 (High)
# WING ZONE                            Restaurant    Risk 1 (High)
# ARBYS                                Restaurant    Risk 1 (High)
# LAS ISLAS MARIAS                     Restaurant    Risk 1 (High)
# MARGARET'S                           Restaurant    Risk 1 (High)
# POPEYES FAMOUS FRIED CHICKEN         Restaurant  Risk 2 (Medium)
# PJ PIZZA COMPANY 1 DBA PAPA JOHNS    Restaurant  Risk 2 (Medium)
# DUNKIN DONUTS                        Restaurant  Risk 2 (Medium)
#
#                                                    Address      Zip  \
# DBA Name
# THE MECCA RESTAURANT                 6666 N NORTHWEST HWY   60631.0
# ...

# %%
#select restaurant 100,1000 and 10000 along with columns 5,3,1
df3.iloc[[100,1000,1000],[5,3,1]]
# Out:
#                     Inspection Type      Zip           Risk
# DBA Name
# TAQUERIA LA CANTERA         License  60608.0  Risk 1 (High)
# PARK TAVERN CHICAGO       Complaint  60612.0  Risk 1 (High)
# PARK TAVERN CHICAGO       Complaint  60612.0  Risk 1 (High)

# %% [markdown]
# **Stack Overflow Dataset**

# %%
df4=pd.read_csv('/content/stackoverflow_qa.csv')
df4
# Out:
#              id         creationdate  score  viewcount  \
# 0       5486226  2011-03-30 12:26:50      4       2113
# 1       5515021  2011-04-01 14:50:44      8       7015
# 2       5558607  2011-04-05 21:13:50      2       7392
# 3       6467832  2011-06-24 12:31:45      9      13056
# 4       7577546  2011-09-28 01:58:38      9       2488
# ...         ...                  ...    ...        ...
# 56393  47606711  2017-12-02 10:07:13      0         17
# 56394  47607549  2017-12-02 11:41:59     -1         41
# 56395  47609325  2017-12-02 15:16:26      0         33
# 56396  47609598  2017-12-02 15:45:40      2         18
# 56397  47611969  2017-12-02 19:59:09     -6         19
#
#                                                    title  answercount  \
# 0                               Rolling median in python            3
# 1           Compute a compounded return series in Python            3
# 2            Sort a pandas DataMatrix in ascending order            2
# ...

# %%
print(df4.columns)
# Out:
# Index(['id', 'creationdate', 'score', 'viewcount', 'title', 'answercount',
#        'commentcount', 'favoritecount', 'quest_name', 'quest_rep', 'ans_name',
#        'ans_rep'],
#       dtype='object')

# %%
print(df4.shape)
# Out:
# (56398, 12)

# %%
#Find all the question that have exactly 5 answers
x=df4['answercount']==5
df4[x]
# Out:
#              id         creationdate  score  viewcount  \
# 75     10373660  2012-04-29 16:10:35    199     207980
# 115    10791661  2012-05-29 00:06:52      7      12210
# 130    10972410  2012-06-10 21:12:43     19      46428
# 189    11391969  2012-07-09 09:04:33     44      27467
# 246    11811392  2012-08-04 19:25:34     17      20051
# ...         ...                  ...    ...        ...
# 53433  47028601  2017-10-31 05:45:19      2         38
# 53752  46557074  2017-10-04 04:33:51      0         61
# 53983  46882557  2017-10-23 05:36:29      3         87
# 54384  47542980  2017-11-29 00:05:31      2         43
# 55444  47213771  2017-11-10 00:13:38      1        247
#
#                                                    title  answercount  \
# 75       Converting a Pandas GroupBy object to DataFrame            5
# 115    How do I discretize values in a pandas DataFra...            5
# 130           pandas: combine two columns in a DataFrame            5
# ...

# %%
#Find all the questions that have less than 10 views
criteria=df4['viewcount']<10
df4[criteria]
# Out:
#              id         creationdate  score  viewcount  \
# 7787   26493306  2014-10-21 18:06:10      1          6
# 17653  33641540  2015-11-10 23:19:36      0          9
# 29414  40062672  2016-10-15 18:24:21     -1          9
# 36086  42538091  2017-03-01 17:20:37      0          9
# 36340  42080039  2017-02-07 01:13:30      0          8
# 40490  43271693  2017-04-07 07:04:19      0          9
# 43489  45069021  2017-07-12 23:22:49      1          9
# 47371  45212468  2017-07-20 10:43:55      0          9
# 49232  45890470  2017-08-25 23:16:57      0          7
# 50461  45991431  2017-08-31 23:26:20      0          9
# 52518  47091256  2017-11-03 08:20:58      0          8
# 53794  46628996  2017-10-08 08:22:26      0          7
# 54304  47208273  2017-11-09 17:38:49      0          6
# 54462  47254707  2017-11-12 22:26:52      0          9
# 54507  47611836  2017-12-02 19:44:00      0          8
# 54855  47126567  2017-11-05 20:58:17      0          9
# ...

# %%
#find where quest_name='Jason Strimple'
criteria3=df4['quest_name']=='Jason Strimpel'
df4[criteria3]
# Out:
#              id         creationdate  score  viewcount  \
# 1       5515021  2011-04-01 14:50:44      8       7015
# 2       5558607  2011-04-05 21:13:50      2       7392
# 883    14509517  2013-01-24 19:49:25      1        962
# 1384   18065948  2013-08-05 19:17:03      1        255
# 1385   17623019  2013-07-12 19:55:49      4        746
# 1386   17576615  2013-07-10 17:00:27      3       6337
# 1387   14940948  2013-02-18 16:33:35      3        515
# 1388   14941097  2013-02-18 16:41:15     28      36875
# 1389   15751283  2013-04-01 20:28:44      7       4610
# 3249   20426287  2013-12-06 14:26:39      0        131
# 6151   25315873  2014-08-14 19:12:55      0        148
# 8776   27640202  2014-12-24 17:12:44      4        877
# 8777   27322502  2014-12-05 18:35:12      1        219
# 19655  35593337  2016-02-24 04:33:58      2        668
# 24994  38261486  2016-07-08 07:48:17      1         74
# 27645  39485160  2016-09-14 07:50:20      0         80
# ...

# %%
#Do both 1 & 2
Do=x & criteria
df4[Do]
# Out:
# Empty DataFrame
# Columns: [id, creationdate, score, viewcount, title, answercount, commentcount, favoritecount, quest_name, quest_rep, ans_name, ans_rep]
# Index: []

# %%
#Find where ans_name='Scott Boston' or ans_name='Ted Petrou' or ans_name='MaxU' or ans_name='unutbu'
c1=df4['ans_name']=='Scott Boston'

c2=df4['ans_name']=='Ted Petrou'

c3=df4['ans_name']=='MaxU'

c4=df4['ans_name']=='unutnu'

# %%
cr_all=c1 | c2 | c3 | c4
df4[cr_all]
# Out:
#              id         creationdate  score  viewcount  \
# 100    10665889  2012-05-19 14:11:42    144     179896
# 19439  35090485  2016-01-29 17:27:59      1         73
# 19450  36107094  2016-03-19 21:00:29      0         73
# 19508  36556256  2016-04-11 18:18:54      2       2155
# 19518  35952314  2016-03-12 00:39:10      2        262
# ...         ...                  ...    ...        ...
# 56254  47580866  2017-11-30 19:05:56      1         41
# 56302  47491733  2017-11-26 00:03:50      0         36
# 56307  47437109  2017-11-22 14:26:13     -2         23
# 56340  47516326  2017-11-27 17:09:21      2         27
# 56382  47581808  2017-11-30 20:12:18      3         27
#
#                                                    title  answercount  \
# 100     How to take column-slices of dataframe in pandas            7
# 19439  How to incorporate a SQL style "is not null" i...            2
# 19450          Pandas apply to all values except missing            1
# ...
